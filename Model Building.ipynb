# %%
# !uv pip install numpy
# Out:
# Using Python 3.10.20 environment at: /home/dilshan/miniconda3/envs/predictor
# Resolved 1 package in 1.02s
# Installed 1 package in 20ms
#  + numpy==2.2.6

# %%
# !uv pip install pandas
# Out:
# Using Python 3.10.20 environment at: /home/dilshan/miniconda3/envs/predictor
# Resolved 6 packages in 1.29s
# Installed 2 packages in 28ms
#  + pandas==2.3.3
#  + pytz==2026.1.post1

# %%
import numpy as np
import pandas as pd
